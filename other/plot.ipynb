# %%
# ref: https://github.com/jrjohansson/scientific-python-lectures/blob/master/Lecture-4-Matplotlib.ipynb
    
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
mpl.rcParams['font.family'] = 'Arial'
mpl.rcParams['font.size'] = 24
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
mpl.rcParams['axes.linewidth']= 3 # bounding box line width
from matplotlib.ticker import MaxNLocator
mpl.rcParams['figure.figsize']
mpl.rcParams.keys
# Out:
# /root/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:886: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))
# <bound method Mapping.keys of RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.avconv_args': [],
#           'animation.avconv_path': 'avconv',
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.html_args': [],
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
# ...

# %% [markdown]
#  NewsCommentary V13 Results

# %%
x_h = [3, 5, 6, 9]
h_results = [[23.22, 22.61, 22.56, 23.37], # bleu
        # [108.35, 110.13,106.24, 110.63], # nist
         [23.43, 23.70, 21.78, 23.84], # rouge-l
         [23.60, 23.67, 22.55, 24.09], # meteror
        ]
x_l = [3, 4, 5, 6]
l_results = [[23.37, 23.23, 24.12, 24.56], # bleu
        # [110.63, 108.17, 110.37, 110.53], # nist
         [23.84, 23.41, 23.66, 23.77], # rouge-l
         [24.09, 23.62, 24.21, 24.33], # meteror
        ]

# %% [markdown]
# WMT19 Zh-En Results

# %%
x_h = [3, 5, 6, 9]
h_results = [[25.10, 25.50, 25.44, 25.27], # bleu
        # [], # nist
         [21.97, 22.50, 22.22, 22.72], # rouge-l
         [21.21, 21.54, 21.42, 21.97], # meteror
        ]
x_l = [3, 4, 5, 6]
l_results = [[25.27, 25.36, 25.18, 25.73], # bleu
        # [], # nist
         [22.72, 23.95, 23.34, 24.48], # rouge-l
         [21.97, 22.89, 22.64, 23.88], # meteror
        ]

# %%
fig, axes = plt.subplots(1,2, figsize=(20,8))
#axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height (range 0 to 1)
colors=['c','b','y','m']
markers=['o','s','d', '^', '+']

metrics=['BLEU', 
        # 'NIST', 
         'ROUGE-L', 
         'METEROR']
for i in range(len(l_results)):
    axes[0].plot(x_l, l_results[i], colors[i], marker=markers[i], markersize=15, linewidth=5, label=metrics[i])
#axes[0].legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3, ncol=3, mode="expand", borderaxespad=0.)
axes[0].legend(bbox_to_anchor=(0.1, 0.5)); # upper left corner
axes[0].grid()
axes[0].set_xlabel('# Transformer layers', fontsize=24)
#axes[0].set_ylabel('BLEU')
#axes[0].set_title('Ablation Results for Number of Layers');
axes[0].xaxis.set_major_locator(MaxNLocator(integer=True))

for i in range(len(h_results)):
    axes[1].plot(x_h, h_results[i], colors[i], marker=markers[i], markersize=15, linewidth=5, label=metrics[i])
axes[1].legend(bbox_to_anchor=(0.2, 0.5)); # upper left corner
axes[1].grid()
axes[1].set_xlabel('# attention heads', fontsize=24)
#axes[1].set_title('Ablation Results for Number of Heads');

fig.tight_layout()
fig.savefig('ablation.png', dpi=200);
